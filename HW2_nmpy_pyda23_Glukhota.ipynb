# %%
import pandas as pd

# %% [markdown]
# ## Задание 1
#
# Скачайте с сайта grouplens.org...movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
movies = pd.read_csv('ratings.csv')
top_films = movies [movies.rating == 5 ]
top_films['movieId'].value_counts().head(1)
# Out:
# 318    153
# Name: movieId, dtype: int64

# %%
# одной строкой
movies [movies.rating == 5 ]['movieId'].value_counts().head(1)
# Out:
# 318    153
# Name: movieId, dtype: int64

# %% [markdown]
# ## Задание 2
#
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
power = pd.read_csv('power.csv')
power.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
sum(power[ (power.quantity >= 0) & 
           (power.category.isin( [4,12,21] )) & 
           (power.country.isin(['Lithuania', 'Estonia', 'Latvia'])) & 
           (power.year >= 2005) &
           (power.year <= 2010) ]
    .quantity )
# Out:
# 240580.0

# %% [markdown]
# ## Задание 3
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц (необязательно брать именно эти):
# https://fortrader.org/quotes
# www.finanz.ru...om-vremeni

# %%
url = 'https://premierliga.ru/tournaments/championship/tournament-table/'

# %%
url_table = pd.read_html(url, header = 0)[3]

# %%
tournament_table = url_table.rename(columns=url_table.iloc[0]).drop(url_table.index[0])
tournament_table
# Out:
#      NaN          Команда NaN  И  В  Н  П з -  п  О NaN  ...  В  Н  П з -  п  \
# 1    1.0            Зенит NaN  2  2  0  0  7 - 3  6 NaN  ...  0  0  0  0 - 0
# 2    2.0            Рубин NaN  2  2  0  0  4 - 0  6 NaN  ...  1  0  0  1 - 0
# 3    3.0        Локомотив NaN  2  2  0  0  5 - 2  6 NaN  ...  1  0  0  3 - 1
# 4    4.0           Динамо NaN  2  2  0  0  5 - 2  6 NaN  ...  0  0  0  0 - 0
# 5    5.0  Нижний Новгород NaN  2  1  1  0  2 - 1  4 NaN  ...  1  0  0  1 - 0
# 6    6.0             Сочи NaN  2  1  0  1  2 - 2  3 NaN  ...  0  0  0  0 - 0
# 7    7.0            Химки NaN  2  1  0  1  2 - 3  3 NaN  ...  0  0  1  1 - 3
# 8    8.0         ПФК ЦСКА NaN  2  1  0  1  2 - 2  3 NaN  ...  1  0  1  2 - 2
# 9    9.0          Спартак NaN  2  1  0  1  1 - 1  3 NaN  ...  0  0  0  0 - 0
# 10  10.0            Ахмат NaN  2  1  0  1  3 - 3  3 NaN  ...  0  0  1  1 - 2
# 11  11.0        Краснодар NaN  2  1  0  1  3 - 1  3 NaN  ...  0  0  1  0 - 1
# ...
